# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import Manuel as mn

# %%
df = mn.cargar_dataset('Mexico.csv')
pd.options.display.max_rows =10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            26281 non-null  int64
#  1   listing_url                                   26281 non-null  object
#  2   scrape_id                                     26281 non-null  int64
#  3   last_scraped                                  26281 non-null  object
#  4   source                                        26281 non-null  object
#  5   name                                          26281 non-null  object
#  6   description                                   25513 non-null  object
#  7   neighborhood_overview                         15110 non-null  object
#  8   picture_url                                   26281 non-null  object
#  9   host_id                                       26281 non-null  int64
#  10  host_url                                      26281 non-null  object
#  11  host_name                                     26278 non-null  object
#  12  host_since                                    26278 non-null  object
#  13  host_location                                 20888 non-null  object
#  14  host_about                                    15678 non-null  object
#  15  host_response_time                            23109 non-null  object
#  16  host_response_rate                            23109 non-null  object
#  17  host_acceptance_rate                          23508 non-null  object
#  18  host_is_superhost                             24899 non-null  object
#  19  host_thumbnail_url                            26278 non-null  object
#  20  host_picture_url                              26278 non-null  object
#  21  host_neighbourhood                            13792 non-null  object
#  22  host_listings_count                           26278 non-null  float64
#  23  host_total_listings_count                     26278 non-null  float64
#  24  host_verifications                            26278 non-null  object
#  25  host_has_profile_pic                          26278 non-null  object
#  26  host_identity_verified                        26278 non-null  object
#  27  neighbourhood                                 15110 non-null  object
#  28  neighbourhood_cleansed                        26281 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      26281 non-null  float64
#  31  longitude                                     26281 non-null  float64
#  32  property_type                                 26281 non-null  object
#  33  room_type                                     26281 non-null  object
#  34  accommodates                                  26281 non-null  int64
#  35  bathrooms                                     22477 non-null  float64
#  36  bathrooms_text                                26253 non-null  object
#  37  bedrooms                                      25330 non-null  float64
#  38  beds                                          22456 non-null  float64
#  39  amenities                                     26281 non-null  object
#  40  price                                         22466 non-null  object
#  41  minimum_nights                                26281 non-null  int64
#  42  maximum_nights                                26281 non-null  int64
#  43  minimum_minimum_nights                        26281 non-null  int64
#  44  maximum_minimum_nights                        26281 non-null  int64
#  45  minimum_maximum_nights                        26281 non-null  int64
#  46  maximum_maximum_nights                        26281 non-null  int64
#  47  minimum_nights_avg_ntm                        26281 non-null  float64
#  48  maximum_nights_avg_ntm                        26281 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              25302 non-null  object
#  51  availability_30                               26281 non-null  int64
#  52  availability_60                               26281 non-null  int64
#  53  availability_90                               26281 non-null  int64
#  54  availability_365                              26281 non-null  int64
#  55  calendar_last_scraped                         26281 non-null  object
#  56  number_of_reviews                             26281 non-null  int64
#  57  number_of_reviews_ltm                         26281 non-null  int64
#  58  number_of_reviews_l30d                        26281 non-null  int64
#  59  first_review                                  22985 non-null  object
#  60  last_review                                   22985 non-null  object
#  61  review_scores_rating                          22985 non-null  float64
#  62  review_scores_accuracy                        22984 non-null  float64
#  63  review_scores_cleanliness                     22984 non-null  float64
#  64  review_scores_checkin                         22984 non-null  float64
#  65  review_scores_communication                   22984 non-null  float64
#  66  review_scores_location                        22984 non-null  float64
#  67  review_scores_value                           22984 non-null  float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              26281 non-null  object
#  70  calculated_host_listings_count                26281 non-null  int64
#  71  calculated_host_listings_count_entire_homes   26281 non-null  int64
#  72  calculated_host_listings_count_private_rooms  26281 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   26281 non-null  int64
#  74  reviews_per_month                             22985 non-null  float64
# dtypes: float64(20), int64(21), object(34)
# memory usage: 15.0+ MB

# %%
mn.cuenta_valores_nulos(df)
pd.options.display.max_rows = None
mn.cuenta_valores_nulos(df)
# Out:
# ('Valores nulos por columna',
#  id                                                  0
#  listing_url                                         0
#  scrape_id                                           0
#  last_scraped                                        0
#  source                                              0
#  name                                                0
#  description                                       768
#  neighborhood_overview                           11171
#  picture_url                                         0
#  host_id                                             0
#  host_url                                            0
#  host_name                                           3
#  host_since                                          3
#  host_location                                    5393
#  host_about                                      10603
#  host_response_time                               3172
#  host_response_rate                               3172
#  host_acceptance_rate                             2773
#  host_is_superhost                                1382
#  host_thumbnail_url                                  3
#  host_picture_url                                    3
#  host_neighbourhood                              12489
#  host_listings_count                                 3
#  host_total_listings_count                           3
#  host_verifications                                  3
#  host_has_profile_pic                                3
#  host_identity_verified                              3
#  neighbourhood                                   11171
#  neighbourhood_cleansed                              0
#  neighbourhood_group_cleansed                    26281
#  latitude                                            0
#  longitude                                           0
#  property_type                                       0
#  room_type                                           0
#  accommodates                                        0
#  bathrooms                                        3804
#  bathrooms_text                                     28
#  bedrooms                                          951
#  beds                                             3825
#  amenities                                           0
#  price                                            3815
#  minimum_nights                                      0
#  maximum_nights                                      0
#  minimum_minimum_nights                              0
#  maximum_minimum_nights                              0
#  minimum_maximum_nights                              0
#  maximum_maximum_nights                              0
#  minimum_nights_avg_ntm                              0
#  maximum_nights_avg_ntm                              0
#  calendar_updated                                26281
#  has_availability                                  979
#  availability_30                                     0
#  availability_60                                     0
#  availability_90                                     0
#  availability_365                                    0
#  calendar_last_scraped                               0
#  number_of_reviews                                   0
#  number_of_reviews_ltm                               0
#  number_of_reviews_l30d                              0
#  first_review                                     3296
#  last_review                                      3296
#  review_scores_rating                             3296
#  review_scores_accuracy                           3297
#  review_scores_cleanliness                        3297
#  review_scores_checkin                            3297
#  review_scores_communication                      3297
#  review_scores_location                           3297
#  review_scores_value                              3297
#  license                                         26281
#  instant_bookable                                    0
#  calculated_host_listings_count                      0
#  calculated_host_listings_count_entire_homes         0
#  calculated_host_listings_count_private_rooms        0
#  calculated_host_listings_count_shared_rooms         0
#  reviews_per_month                                3296
#  dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(187332))

# %%
data = df.fillna(method="bfill")
data = df.fillna(method="ffill")
data["license"] = data["license"].fillna(0)
data

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
# name                                                0
# description                                         0
# neighborhood_overview                               0
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           0
# host_since                                          0
# host_location                                       0
# host_about                                          0
# host_response_time                                  1
# host_response_rate                                  1
# host_acceptance_rate                                1
# host_is_superhost                                   0
# host_thumbnail_url                                  0
# host_picture_url                                    0
# host_neighbourhood                                  1
# host_listings_count                                 0
# host_total_listings_count                           0
# host_verifications                                  0
# host_has_profile_pic                                0
# host_identity_verified                              0
# neighbourhood                                       0
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                    26281
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                           0
# bathrooms_text                                      0
# bedrooms                                            0
# beds                                                0
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              0
# maximum_minimum_nights                              0
# minimum_maximum_nights                              0
# maximum_maximum_nights                              0
# minimum_nights_avg_ntm                              0
# maximum_nights_avg_ntm                              0
# calendar_updated                                26281
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# first_review                                        1
# last_review                                         1
# review_scores_rating                                1
# review_scores_accuracy                              1
# review_scores_cleanliness                           1
# review_scores_checkin                               1
# review_scores_communication                         1
# review_scores_location                              1
# review_scores_value                                 1
# license                                             0
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                   1
# dtype: int64

# %%
data["host_response_time"] = data["host_response_time"].fillna(0)

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
# name                                                0
# description                                         0
# neighborhood_overview                               0
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           0
# host_since                                          0
# host_location                                       0
# host_about                                          0
# host_response_time                                  0
# host_response_rate                                  1
# host_acceptance_rate                                1
# host_is_superhost                                   0
# host_thumbnail_url                                  0
# host_picture_url                                    0
# host_neighbourhood                                  1
# host_listings_count                                 0
# host_total_listings_count                           0
# host_verifications                                  0
# host_has_profile_pic                                0
# host_identity_verified                              0
# neighbourhood                                       0
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                    26281
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                           0
# bathrooms_text                                      0
# bedrooms                                            0
# beds                                                0
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              0
# maximum_minimum_nights                              0
# minimum_maximum_nights                              0
# maximum_maximum_nights                              0
# minimum_nights_avg_ntm                              0
# maximum_nights_avg_ntm                              0
# calendar_updated                                26281
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# first_review                                        1
# last_review                                         1
# review_scores_rating                                1
# review_scores_accuracy                              1
# review_scores_cleanliness                           1
# review_scores_checkin                               1
# review_scores_communication                         1
# review_scores_location                              1
# review_scores_value                                 1
# license                                             0
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                   1
# dtype: int64

# %%
data["host_response_rate"] = data["host_response_rate"].fillna(0)

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
# name                                                0
# description                                         0
# neighborhood_overview                               0
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           0
# host_since                                          0
# host_location                                       0
# host_about                                          0
# host_response_time                                  0
# host_response_rate                                  0
# host_acceptance_rate                                1
# host_is_superhost                                   0
# host_thumbnail_url                                  0
# host_picture_url                                    0
# host_neighbourhood                                  1
# host_listings_count                                 0
# host_total_listings_count                           0
# host_verifications                                  0
# host_has_profile_pic                                0
# host_identity_verified                              0
# neighbourhood                                       0
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                    26281
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                           0
# bathrooms_text                                      0
# bedrooms                                            0
# beds                                                0
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              0
# maximum_minimum_nights                              0
# minimum_maximum_nights                              0
# maximum_maximum_nights                              0
# minimum_nights_avg_ntm                              0
# maximum_nights_avg_ntm                              0
# calendar_updated                                26281
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# first_review                                        1
# last_review                                         1
# review_scores_rating                                1
# review_scores_accuracy                              1
# review_scores_cleanliness                           1
# review_scores_checkin                               1
# review_scores_communication                         1
# review_scores_location                              1
# review_scores_value                                 1
# license                                             0
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                   1
# dtype: int64

# %%
data["host_acceptance_rate"] = data["host_acceptance_rate"].fillna(0)

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
# name                                                0
# description                                         0
# neighborhood_overview                               0
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           0
# host_since                                          0
# host_location                                       0
# host_about                                          0
# host_response_time                                  0
# host_response_rate                                  0
# host_acceptance_rate                                0
# host_is_superhost                                   0
# host_thumbnail_url                                  0
# host_picture_url                                    0
# host_neighbourhood                                  1
# host_listings_count                                 0
# host_total_listings_count                           0
# host_verifications                                  0
# host_has_profile_pic                                0
# host_identity_verified                              0
# neighbourhood                                       0
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                    26281
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                           0
# bathrooms_text                                      0
# bedrooms                                            0
# beds                                                0
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              0
# maximum_minimum_nights                              0
# minimum_maximum_nights                              0
# maximum_maximum_nights                              0
# minimum_nights_avg_ntm                              0
# maximum_nights_avg_ntm                              0
# calendar_updated                                26281
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# first_review                                        1
# last_review                                         1
# review_scores_rating                                1
# review_scores_accuracy                              1
# review_scores_cleanliness                           1
# review_scores_checkin                               1
# review_scores_communication                         1
# review_scores_location                              1
# review_scores_value                                 1
# license                                             0
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                   1
# dtype: int64

# %%
data["host_neighbourhood"] = data["host_neighbourhood"].fillna(0)

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
# name                                                0
# description                                         0
# neighborhood_overview                               0
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           0
# host_since                                          0
# host_location                                       0
# host_about                                          0
# host_response_time                                  0
# host_response_rate                                  0
# host_acceptance_rate                                0
# host_is_superhost                                   0
# host_thumbnail_url                                  0
# host_picture_url                                    0
# host_neighbourhood                                  0
# host_listings_count                                 0
# host_total_listings_count                           0
# host_verifications                                  0
# host_has_profile_pic                                0
# host_identity_verified                              0
# neighbourhood                                       0
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                    26281
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                           0
# bathrooms_text                                      0
# bedrooms                                            0
# beds                                                0
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              0
# maximum_minimum_nights                              0
# minimum_maximum_nights                              0
# maximum_maximum_nights                              0
# minimum_nights_avg_ntm                              0
# maximum_nights_avg_ntm                              0
# calendar_updated                                26281
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# first_review                                        1
# last_review                                         1
# review_scores_rating                                1
# review_scores_accuracy                              1
# review_scores_cleanliness                           1
# review_scores_checkin                               1
# review_scores_communication                         1
# review_scores_location                              1
# review_scores_value                                 1
# license                                             0
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                   1
# dtype: int64

# %%
data["neighbourhood_group_cleansed"] = data["neighbourhood_group_cleansed"].fillna(0)

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
# name                                                0
# description                                         0
# neighborhood_overview                               0
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           0
# host_since                                          0
# host_location                                       0
# host_about                                          0
# host_response_time                                  0
# host_response_rate                                  0
# host_acceptance_rate                                0
# host_is_superhost                                   0
# host_thumbnail_url                                  0
# host_picture_url                                    0
# host_neighbourhood                                  0
# host_listings_count                                 0
# host_total_listings_count                           0
# host_verifications                                  0
# host_has_profile_pic                                0
# host_identity_verified                              0
# neighbourhood                                       0
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                        0
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                           0
# bathrooms_text                                      0
# bedrooms                                            0
# beds                                                0
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              0
# maximum_minimum_nights                              0
# minimum_maximum_nights                              0
# maximum_maximum_nights                              0
# minimum_nights_avg_ntm                              0
# maximum_nights_avg_ntm                              0
# calendar_updated                                26281
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# first_review                                        1
# last_review                                         1
# review_scores_rating                                1
# review_scores_accuracy                              1
# review_scores_cleanliness                           1
# review_scores_checkin                               1
# review_scores_communication                         1
# review_scores_location                              1
# review_scores_value                                 1
# license                                             0
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                   1
# dtype: int64

# %%
data["calendar_updated"] = data["calendar_updated"].fillna(0)
data["first_review"] = data["first_review"].fillna(0)
data["last_review"] = data["last_review"].fillna(0)
data["review_scores_rating"] = data["review_scores_rating"].fillna(0)
data["review_scores_accuracy"] = data["review_scores_accuracy"].fillna(0)
data["review_scores_cleanliness"] = data["review_scores_cleanliness"].fillna(0)
data["review_scores_checkin"] = data["review_scores_checkin"].fillna(0)
data["review_scores_communication"] = data["review_scores_communication"].fillna(0)
data["review_scores_location"] = data["review_scores_location"].fillna(0)
data["review_scores_value"] = data["review_scores_value"].fillna(0)
data["reviews_per_month"] = data["reviews_per_month"].fillna(0)

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
# name                                            0
# description                                     0
# neighborhood_overview                           0
# picture_url                                     0
# host_id                                         0
# host_url                                        0
# host_name                                       0
# host_since                                      0
# host_location                                   0
# host_about                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_thumbnail_url                              0
# host_picture_url                                0
# host_neighbourhood                              0
# host_listings_count                             0
# host_total_listings_count                       0
# host_verifications                              0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood                                   0
# neighbourhood_cleansed                          0
# neighbourhood_group_cleansed                    0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms                                       0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# amenities                                       0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# has_availability                                0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# calendar_last_scraped                           0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# first_review                                    0
# last_review                                     0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# license                                         0
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %%
#Creo 2 dataframe para poder procesar los outliers
cuantitativas = data.select_dtypes(include=['float64', 'int64', 'float', 'int'])
cualitativas = data.select_dtypes(include=['object','datetime','category'])

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15,8))
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atípicos Del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = cuantitativas

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.25*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido id                                              2.600145e+18
# scrape_id                                       2.024123e+13
# host_id                                         8.860262e+08
# host_listings_count                             3.350000e+01
# host_total_listings_count                       3.950000e+01
# neighbourhood_group_cleansed                    0.000000e+00
# latitude                                        1.949298e+01
# longitude                                      -9.911830e+01
# accommodates                                    7.000000e+00
# bathrooms                                       3.500000e+00
# bedrooms                                        3.500000e+00
# beds                                            3.500000e+00
# minimum_nights                                  3.500000e+00
# maximum_nights                                  2.542500e+03
# minimum_minimum_nights                          3.500000e+00
# maximum_minimum_nights                          6.000000e+00
# minimum_maximum_nights                          2.265000e+03
# maximum_maximum_nights                          2.265000e+03
# minimum_nights_avg_ntm                          5.250000e+00
# maximum_nights_avg_ntm                          2.265000e+03
# calendar_updated                                0.000000e+00
# availability_30                                 6.200000e+01
# availability_60                                 1.165000e+02
# availability_90                                 1.675000e+02
# availability_365                                7.390000e+02
# number_of_reviews                               1.480000e+02
# number_of_reviews_ltm                           5.500000e+01
# number_of_reviews_l30d                          5.000000e+00
# review_scores_rating                            5.350000e+00
# review_scores_accuracy                          5.325000e+00
# review_scores_cleanliness                       5.375000e+00
# review_scores_checkin                           5.270000e+00
# review_scores_communication                     5.285000e+00
# review_scores_location                          5.300000e+00
# review_scores_value                             5.295000e+00
# license                                         0.000000e+00
# calculated_host_listings_count                  2.600000e+01
# calculated_host_listings_count_entire_homes     1.500000e+01
# calculated_host_listings_count_private_rooms    5.000000e+00
# calculated_host_listings_count_shared_rooms     0.000000e+00
# reviews_per_month                               5.620000e+00
# dtype: float64
# Limite inferior permitido id                                             -1.300073e+18
# scrape_id                                       2.024123e+13
# host_id                                        -3.658337e+08
# host_listings_count                            -1.525000e+01
# host_total_listings_count                      -1.675000e+01
# neighbourhood_group_cleansed                    0.000000e+00
# latitude                                        1.934028e+01
# longitude                                      -9.920932e+01
# accommodates                                   -5.000000e-01
# bathrooms                                      -2.500000e-01
# bedrooms                                       -2.500000e-01
# beds                                           -2.500000e-01
# minimum_nights                                 -2.500000e-01
# maximum_nights                                 -1.001250e+03
# minimum_minimum_nights                         -2.500000e-01
# maximum_minimum_nights                         -1.500000e+00
# minimum_maximum_nights                         -5.850000e+02
# maximum_maximum_nights                         -5.850000e+02
# minimum_nights_avg_ntm                         -1.125000e+00
# maximum_nights_avg_ntm                         -5.850000e+02
# calendar_updated                                0.000000e+00
# availability_30                                -2.800000e+01
# availability_60                                -3.725000e+01
# availability_90                                -3.875000e+01
# availability_365                               -2.360000e+02
# number_of_reviews                              -6.950000e+01
# number_of_reviews_ltm                          -2.750000e+01
# number_of_reviews_l30d                         -2.500000e+00
# review_scores_rating                            4.375000e+00
# review_scores_accuracy                          4.462500e+00
# review_scores_cleanliness                       4.362500e+00
# review_scores_checkin                           4.595000e+00
# review_scores_communication                     4.572500e+00
# review_scores_location                          4.550000e+00
# review_scores_value                             4.357500e+00
# license                                         0.000000e+00
# calculated_host_listings_count                 -1.150000e+01
# calculated_host_listings_count_entire_homes    -7.500000e+00
# calculated_host_listings_count_private_rooms   -2.500000e+00
# calculated_host_listings_count_shared_rooms     0.000000e+00
# reviews_per_month                              -2.105000e+00
# dtype: float64

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativas['review_scores_checkin'].plot(kind='box', vert=False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr = cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr

# %%
#Coroboramos valores nulos del dataframe LIMPIO
valores_nulos = data3_iqr.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# scrape_id                                          0
# host_id                                            0
# host_listings_count                             3521
# host_total_listings_count                       3696
# neighbourhood_group_cleansed                       0
# latitude                                        2249
# longitude                                       3145
# accommodates                                    1320
# bathrooms                                        689
# bedrooms                                         889
# beds                                            2730
# minimum_nights                                  3523
# maximum_nights                                     0
# minimum_minimum_nights                          3065
# maximum_minimum_nights                          1964
# minimum_maximum_nights                             0
# maximum_maximum_nights                            12
# minimum_nights_avg_ntm                          1973
# maximum_nights_avg_ntm                            11
# calendar_updated                                   0
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# number_of_reviews                               2177
# number_of_reviews_ltm                           1207
# number_of_reviews_l30d                           889
# review_scores_rating                            1944
# review_scores_accuracy                          2009
# review_scores_cleanliness                       2007
# review_scores_checkin                           2192
# review_scores_communication                     2434
# review_scores_location                          2024
# review_scores_value                             2240
# license                                            0
# calculated_host_listings_count                  3380
# calculated_host_listings_count_entire_homes     3917
# calculated_host_listings_count_private_rooms    3169
# calculated_host_listings_count_shared_rooms      382
# reviews_per_month                               1009
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data4_iqr =data3_iqr.copy()
data4_iqr = data4_iqr.fillna(round(data3_iqr.mean(), 1))
data4_iqr

# %%
valores_nulos=data4_iqr.isnull().sum()
valores_nulos
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_listings_count                             0
# host_total_listings_count                       0
# neighbourhood_group_cleansed                    0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# license                                         0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %%
#Unimos el dataframe cuantitativo limpio con el dataframe cualitativo

Datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
Datos_limpios

# %%
#Convertir a csv
Datos_limpios.to_csv("Datos_limpios_Mexico.csv")
